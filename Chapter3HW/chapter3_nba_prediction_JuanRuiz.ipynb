# %%
#February 16, 2020
#Chapter 3
#Predicting Sports Winners with Decision Trees

# %%
#Loads the NBA 2015-2016 season data using pandas, read_csv function
import pandas as pd
data_filename = "basketball.csv"
dataset = pd.read_csv(data_filename)

# %%
#prints out full data frame
dataset.head()
# Out:
#               Date Start (ET)       Visitor/Neutral  PTS  \
# 0  Tue Oct 27 2015      8:00p       Detroit Pistons  106
# 1  Tue Oct 27 2015      8:00p   Cleveland Cavaliers   95
# 2  Tue Oct 27 2015     10:30p  New Orleans Pelicans   95
# 3  Wed Oct 28 2015      7:00p    Washington Wizards   88
# 4  Wed Oct 28 2015      7:30p        Indiana Pacers   99
#
#             Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend. Notes
# 0          Atlanta Hawks     94  Box Score        NaN    19187   NaN
# 1          Chicago Bulls     97  Box Score        NaN    21957   NaN
# 2  Golden State Warriors    111  Box Score        NaN    19596   NaN
# 3          Orlando Magic     87  Box Score        NaN    18846   NaN
# 4        Toronto Raptors    106  Box Score        NaN    19800   NaN

# %%
#Changes the heading after loading the file to clean up the display of the data
dataset = pd.read_csv(data_filename, parse_dates=["Date"])

dataset.columns = ["Date", "Start (ET)", "Visitor Team", "VisitorPts", "Home Team", "HomePts", "OT?", "Score Type", "Attendance", "Notes"]

# %%
#Uses pandas to check the data types of the data, the date is in datetime64[ns] type , any number is int64, any string of words is object
print(dataset.dtypes)
# Out:
# Date            datetime64[ns]
# Start (ET)              object
# Visitor Team            object
# VisitorPts               int64
# Home Team               object
# HomePts                  int64
# OT?                     object
# Score Type              object
# Attendance               int64
# Notes                   object
# dtype: object

# %%
#Specifies the dataset, computes the winner of the match, using a comparision of points : Home Wins when visitor points < home point
dataset["HomeWin"] = dataset["VisitorPts"] < dataset["HomePts"]

# %%
#Displays the data, HomeWin shown using boolean of true or false, according to previous calculation
dataset.head()
# Out:
#         Date Start (ET)          Visitor Team  VisitorPts  \
# 0 2015-10-27      8:00p       Detroit Pistons         106
# 1 2015-10-27      8:00p   Cleveland Cavaliers          95
# 2 2015-10-27     10:30p  New Orleans Pelicans          95
# 3 2015-10-28      7:00p    Washington Wizards          88
# 4 2015-10-28      7:30p        Indiana Pacers          99
#
#                Home Team  HomePts        OT? Score Type  Attendance Notes  \
# 0          Atlanta Hawks       94  Box Score        NaN       19187   NaN
# 1          Chicago Bulls       97  Box Score        NaN       21957   NaN
# 2  Golden State Warriors      111  Box Score        NaN       19596   NaN
# 3          Orlando Magic       87  Box Score        NaN       18846   NaN
# 4        Toronto Raptors      106  Box Score        NaN       19800   NaN
#
#    HomeWin
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True

# %%
#Copies the values of dataset["HomeWin"] into a NumPy array called y_true to use for scikit-learn classifiers, work around as there is no clean integration with pandas and scikit-learn
y_true = dataset["HomeWin"].values

# %%
#Calculates the mean to predict the "Home Field Advantage"
dataset["HomeWin"].mean()
# Out:
# 0.5942249240121581

# %%
#Creates a default dictionary to store the team's last result
from collections import defaultdict
won_last = defaultdict(int)

# %%
#Creates two new features on the data set 
dataset["HomeLastWin"] = 0
dataset["VisitorLastWin"] = 0

# %%
#For sorted dataset, in chronological order, iterates through the rows in the dictionary and updates each row with the latest result
#The last two lines update the features in the dictionary with a 1 if the home team wins, or a 0 if the visiting team wins
for index, row in dataset.iterrows():
    home_team = row["Home Team"]
    visitor_team = row["Visitor Team"]
    row["HomeLastWin"] = won_last[home_team]
    dataset.at[index, "HomeLastWin"] = won_last[home_team] #dataset.set_value(index, "HomeLastWin", won_last[home_team])
    dataset.at[index, "VisitorLastWin"] = won_last[visitor_team] #dataset.set_value(index, "VisitorLastWin", won_last[visitor_team])
    
    won_last[home_team] = int(row["HomeWin"])
    won_last[visitor_team] = 1 - int(row["HomeWin"])

# %%
#Displays the first six rows of the data set
dataset.head(6)
# Out:
#         Date Start (ET)          Visitor Team  VisitorPts  \
# 0 2015-10-27      8:00p       Detroit Pistons         106
# 1 2015-10-27      8:00p   Cleveland Cavaliers          95
# 2 2015-10-27     10:30p  New Orleans Pelicans          95
# 3 2015-10-28      7:00p    Washington Wizards          88
# 4 2015-10-28      7:30p        Indiana Pacers          99
# 5 2015-10-28      7:30p     Charlotte Hornets          94
#
#                Home Team  HomePts        OT? Score Type  Attendance Notes  \
# 0          Atlanta Hawks       94  Box Score        NaN       19187   NaN
# 1          Chicago Bulls       97  Box Score        NaN       21957   NaN
# 2  Golden State Warriors      111  Box Score        NaN       19596   NaN
# 3          Orlando Magic       87  Box Score        NaN       18846   NaN
# 4        Toronto Raptors      106  Box Score        NaN       19800   NaN
# 5             Miami Heat      104  Box Score        NaN       19724   NaN
#
#    HomeWin  HomeLastWin  VisitorLastWin
# 0    False            0               0
# 1     True            0               0
# 2     True            0               0
# 3    False            0               0
# 4     True            0               0
# 5     True            0               0

# %%
#Uses panda's indexer to examine parts of the data set, specifically .loc for label based indexing  
dataset.loc[1000:1005]
# Out:
#            Date Start (ET)           Visitor Team  VisitorPts  \
# 1000 2016-03-15      8:30p   Los Angeles Clippers          87
# 1001 2016-03-15     10:30p       Sacramento Kings         106
# 1002 2016-03-16      7:00p  Oklahoma City Thunder         130
# 1003 2016-03-16      7:00p          Orlando Magic          99
# 1004 2016-03-16      7:00p       Dallas Mavericks          98
# 1005 2016-03-16      7:00p          Chicago Bulls          96
#
#                 Home Team  HomePts        OT? Score Type  Attendance Notes  \
# 1000    San Antonio Spurs      108  Box Score        NaN       18418   NaN
# 1001   Los Angeles Lakers       98  Box Score        NaN       18997   NaN
# 1002       Boston Celtics      109  Box Score        NaN       18624   NaN
# 1003    Charlotte Hornets      107  Box Score        NaN       16148   NaN
# 1004  Cleveland Cavaliers       99  Box Score        NaN       20562   NaN
# 1005   Washington Wizards      117  Box Score        NaN       19556   NaN
#
#       HomeWin  HomeLastWin  VisitorLastWin
# 1000     True            1               0
# 1001    False            0               0
# 1002    False            0               1
# 1003     True            0               1
# 1004     True            0               1
# 1005     True            1               1

# %%
#Creams a dataset using the last win values for the home and visiting team, will be used to specify the columns we use and extract data to use with scikit-learn
X_previouswins = dataset[["HomeLastWin", "VisitorLastWin"]].values

# %%
#Imports DecisionTree Classifier and creates a Decision Tree using 14 as the random_State point 
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=14)

# %%
#Imports cross_val_score method to find the average
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
#Uses scikit-learn to find the average
scores = cross_val_score(clf, X_previouswins, y_true,
scoring='accuracy')
print("Accuracy: {0:.1f}%".format(np.mean(scores) * 100))
# Out:
# Accuracy: 59.4%
# C:\Users\JRuiz\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)

# %%
#Import the 2015 NBA standings for comparision using CSV
import os
standings_filename = os.path.join("standings.csv")

standings = pd.read_csv(standings_filename, skiprows=1)

# %%
#Prints out the table for standings
standings.head()
# Out:
#    Rk                   Team Overall   Home   Road      E      W     A     C  \
# 0   1  Golden State Warriors   67-15   39-2  28-13   25-5  42-10   9-1   7-3
# 1   2          Atlanta Hawks   60-22   35-6  25-16  38-14   22-8  12-6  14-4
# 2   3        Houston Rockets   56-26  30-11  26-15   23-7  33-19   9-1   8-2
# 3   4   Los Angeles Clippers   56-26  30-11  26-15  19-11  37-15   7-3   6-4
# 4   5      Memphis Grizzlies   55-27  31-10  24-17  20-10  35-17   8-2   5-5
#
#      SE  ...   Post   ≤3    ≥10  Oct   Nov   Dec   Jan  Feb   Mar  Apr
# 0   9-1  ...   25-6  5-3   45-9  1-0  13-2  11-3  12-3  8-3  16-2  6-2
# 1  12-4  ...  17-11  6-4  30-10  0-1   9-5  14-2  17-0  7-4   9-7  4-3
# 2   6-4  ...   20-9  8-4  31-14  2-0  11-4   9-5  11-6  7-3  10-6  6-2
# 3   6-4  ...   21-7  3-5   33-9  2-0   9-5  11-6  11-4  5-6  11-5  7-0
# 4   7-3  ...  16-13  9-3  26-13  2-0  13-2   8-6  12-4  7-4   9-8  4-3
#
# [5 rows x 24 columns]

# %%
#Iterate over the rows, and looks up the standings for the home and away team to get a sense of their records
dataset["HomeTeamRanksHigher"] = 0
for index, row in dataset.iterrows():
    home_team = row["Home Team"]
    visitor_team = row["Visitor Team"]
    home_rank = standings[standings["Team"] == home_team]["Rk"].values[0]
    visitor_rank = standings[standings["Team"] == visitor_team]["Rk"].values[0]
    row["HomeTeamRanksHigher"] = int(home_rank > visitor_rank) 
    dataset.iloc[index] = row
    #dataset.set_value(index, "HomeTeamRanksHigher", int(home_rank < visitor_rank))

# %%
#Extracts the dataset
X_homehigher = dataset[[ "HomeTeamRanksHigher", "HomeLastWin", "VisitorLastWin",]].values

# %%
#Uses cross_val_score function to test the result
clf = DecisionTreeClassifier(random_state=14, criterion="entropy")

scores = cross_val_score(clf, X_homehigher, y_true, scoring='accuracy')

print("Accuracy: {0:.1f}%".format(np.mean(scores) * 100))
# Out:
# Accuracy: 60.9%
# C:\Users\JRuiz\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)

# %%
#Tests out which team won the last head-to-head match for the purpose of predicting certain matchup results, as some teams can play better again others
#Creates a dictionary to store the feature in the dataframe, creates a tuple called teams, stores the result in the dictionary, during game time 
#Recreates tuple and examines the previous result
last_match_winner = defaultdict(int)
dataset["HomeTeamWonLast"] = 0

for index, row in dataset.iterrows():
    home_team = row["Home Team"]
    visitor_team = row["Visitor Team"]
    teams = tuple(sorted([home_team, visitor_team]))  # Sort for a consistent ordering
    # Set in the row, who won the last encounter
    home_team_won_last = 1 if last_match_winner[teams] == row["Home Team"] else 0
    dataset.at[index, "HomeTeamWonLast"] = home_team_won_last #dataset.set_value(index, "HomeTeamWonLast", home_team_won_last)
    # Who won this one?
    winner = row["Home Team"] if row["HomeWin"] else row["Visitor Team"]
    last_match_winner[teams] = winner

# %%
#Prints out the given rows of the dataset
dataset.loc[400:450]
# Out:
#           Date Start (ET)            Visitor Team  VisitorPts  \
# 400 2015-12-19      8:00p    Los Angeles Clippers          97
# 401 2015-12-19      8:00p          Indiana Pacers          84
# 402 2015-12-20      1:00p  Minnesota Timberwolves         100
# 403 2015-12-20      1:00p  Portland Trail Blazers         109
# 404 2015-12-20      3:30p      Philadelphia 76ers          86
# 405 2015-12-20      5:00p         Milwaukee Bucks         101
# 406 2015-12-20      6:00p           Atlanta Hawks         103
# 407 2015-12-20      6:00p        Sacramento Kings         104
# 408 2015-12-20      8:00p    New Orleans Pelicans         130
# 409 2015-12-21      7:00p        Sacramento Kings          99
# 410 2015-12-21      7:30p  Minnesota Timberwolves          99
# 411 2015-12-21      7:30p           Orlando Magic         107
# 412 2015-12-21      8:00p  Portland Trail Blazers          97
# 413 2015-12-21      8:00p           Brooklyn Nets         105
# 414 2015-12-21      8:00p       Charlotte Hornets          95
# 415 2015-12-21      8:30p          Indiana Pacers          92
# 416 2015-12-21      9:00p            Phoenix Suns          89
# 417 2015-12-21     10:30p   Oklahoma City Thunder         100
# 418 2015-12-22      7:00p       Memphis Grizzlies         104
# 419 2015-12-22      7:30p         Detroit Pistons          93
# 420 2015-12-22      7:30p        Dallas Mavericks          99
# 421 2015-12-22      9:00p      Los Angeles Lakers         111
# 422 2015-12-23      7:00p          Boston Celtics         102
# 423 2015-12-23      7:00p         New York Knicks          84
# 424 2015-12-23      7:00p        Sacramento Kings         108
# 425 2015-12-23      7:00p         Houston Rockets         101
# 426 2015-12-23      7:00p       Memphis Grizzlies          91
# 427 2015-12-23      7:30p        Dallas Mavericks         119
# 428 2015-12-23      8:00p         Detroit Pistons         100
# 429 2015-12-23      8:00p      Philadelphia 76ers         100
# 430 2015-12-23      8:00p       San Antonio Spurs         108
# 431 2015-12-23      8:00p  Portland Trail Blazers          89
# 432 2015-12-23      9:00p          Denver Nuggets         104
# 433 2015-12-23     10:30p               Utah Jazz          85
# 434 2015-12-23     10:30p   Oklahoma City Thunder         120
# 435 2015-12-25     12:00p    New Orleans Pelicans          88
# 436 2015-12-25      2:30p           Chicago Bulls         105
# 437 2015-12-25      5:00p     Cleveland Cavaliers          83
# 438 2015-12-25      8:00p       San Antonio Spurs          84
# 439 2015-12-25     10:30p    Los Angeles Clippers          94
# 440 2015-12-26      4:00p      Washington Wizards         111
# 441 2015-12-26      5:00p         Toronto Raptors         111
# 442 2015-12-26      7:00p       Memphis Grizzlies          92
# 443 2015-12-26      7:00p         Houston Rockets         108
# 444 2015-12-26      7:00p              Miami Heat         108
# 445 2015-12-26      7:30p         New York Knicks          98
# 446 2015-12-26      7:30p          Boston Celtics          99
# 447 2015-12-26      8:00p          Indiana Pacers         102
# 448 2015-12-26      8:30p           Chicago Bulls         111
# 449 2015-12-26      8:30p          Denver Nuggets          86
# 450 2015-12-26      9:00p      Philadelphia 76ers         111
#
#                   Home Team  HomePts        OT? Score Type  Attendance Notes  \
# 400         Houston Rockets      107  Box Score        NaN       18212   NaN
# 401       Memphis Grizzlies       96  Box Score        NaN       18119   NaN
# 402           Brooklyn Nets       85  Box Score        NaN       14552   NaN
# 403              Miami Heat      116  Box Score        NaN       19600   NaN
# 404     Cleveland Cavaliers      108  Box Score        NaN       20562   NaN
# 405            Phoenix Suns       95  Box Score        NaN       16859   NaN
# 406           Orlando Magic      100  Box Score        NaN       16982   NaN
# 407         Toronto Raptors       94  Box Score        NaN       19800   NaN
# 408          Denver Nuggets      125  Box Score        NaN       13857   NaN
# 409      Washington Wizards      113  Box Score        NaN       15124   NaN
# 410          Boston Celtics      113  Box Score        NaN       18624   NaN
# 411         New York Knicks       99  Box Score        NaN       19812   NaN
# 412           Atlanta Hawks      106  Box Score        NaN       18373   NaN
# 413           Chicago Bulls      102  Box Score        NaN       21825   NaN
# 414         Houston Rockets      102  Box Score        NaN       18236   NaN
# 415       San Antonio Spurs      106  Box Score        NaN       18418   NaN
# 416               Utah Jazz      110  Box Score        NaN       19911   NaN
# 417    Los Angeles Clippers       99  Box Score        NaN       19415   NaN
# 418      Philadelphia 76ers       90  Box Score        NaN       15552   NaN
# 419              Miami Heat       92  Box Score        NaN       19901   NaN
# 420         Toronto Raptors      103  Box Score        NaN       19800   NaN
# 421          Denver Nuggets      107  Box Score        NaN       19124   NaN
# 422       Charlotte Hornets       89  Box Score        NaN       19082   NaN
# 423     Cleveland Cavaliers       91  Box Score        NaN       20562   NaN
# 424          Indiana Pacers      106  Box Score        NaN       18165   NaN
# 425           Orlando Magic      104  Box Score        NaN       17061   NaN
# 426      Washington Wizards      100  Box Score        NaN       15879   NaN
# 427           Brooklyn Nets      118  Box Score         OT       15994   NaN
# 428           Atlanta Hawks      107  Box Score        NaN       17575   NaN
# 429         Milwaukee Bucks      113  Box Score        NaN       15754   NaN
# 430  Minnesota Timberwolves       83  Box Score        NaN       16788   NaN
# 431    New Orleans Pelicans      115  Box Score        NaN       16686   NaN
# 432            Phoenix Suns       96  Box Score        NaN       17034   NaN
# 433   Golden State Warriors      103  Box Score        NaN       19596   NaN
# 434      Los Angeles Lakers       85  Box Score        NaN       18997   NaN
# 435              Miami Heat       94  Box Score         OT       19845   NaN
# 436   Oklahoma City Thunder       96  Box Score        NaN       18203   NaN
# 437   Golden State Warriors       89  Box Score        NaN       19596   NaN
# 438         Houston Rockets       88  Box Score        NaN       18319   NaN
# 439      Los Angeles Lakers       84  Box Score        NaN       18997   NaN
# 440           Brooklyn Nets       96  Box Score        NaN       17732   NaN
# 441         Milwaukee Bucks       90  Box Score        NaN       16329   NaN
# 442       Charlotte Hornets       98  Box Score        NaN       19091   NaN
# 443    New Orleans Pelicans      110  Box Score        NaN       18248   NaN
# 444           Orlando Magic      101  Box Score        NaN       18846   NaN
# 445           Atlanta Hawks      117  Box Score        NaN       19015   NaN
# 446         Detroit Pistons       93  Box Score        NaN       18288   NaN
# 447  Minnesota Timberwolves       88  Box Score        NaN       15076   NaN
# 448        Dallas Mavericks      118  Box Score        NaN       20392   NaN
# 449       San Antonio Spurs      101  Box Score        NaN       18420   NaN
# 450            Phoenix Suns      104  Box Score        NaN       17548   NaN
#
#      HomeWin  HomeLastWin  VisitorLastWin  HomeTeamRanksHigher  \
# 400     True            1               0                    0
# 401     True            0               1                    0
# 402    False            0               1                    0
# 403     True            0               0                    1
# 404     True            1               0                    0
# 405    False            1               0                    1
# 406    False            1               1                    1
# 407    False            1               0                    0
# 408    False            0               0                    1
# 409     True            1               1                    0
# 410     True            0               1                    0
# 411    False            1               0                    1
# 412     True            1               0                    0
# 413    False            0               0                    0
# 414     True            1               0                    0
# 415     True            1               0                    0
# 416     True            1               0                    1
# 417    False            0               1                    0
# 418    False            0               1                    1
# 419    False            1               1                    0
# 420     True            0               1                    1
# 421    False            0               0                    0
# 422    False            0               1                    1
# 423     True            1               0                    0
# 424    False            0               0                    0
# 425     True            1               1                    1
# 426     True            1               1                    1
# 427    False            1               0                    1
# 428     True            1               1                    0
# 429     True            1               0                    0
# 430    False            0               1                    1
# 431     True            1               0                    1
# 432    False            0               0                    0
# 433     True            1               1                    0
# 434    False            1               1                    1
# 435     True            0               1                    1
# 436    False            1               0                    1
# 437     True            1               1                    0
# 438     True            0               1                    0
# 439    False            0               0                    1
# 440    False            0               1                    1
# 441    False            1               1                    1
# 442     True            0               0                    1
# 443     True            0               1                    1
# 444    False            1               1                    1
# 445     True            1               0                    0
# 446    False            0               1                    1
# 447    False            0               0                    1
# 448     True            1               1                    1
# 449     True            0               1                    0
# 450    False            0               0                    0
#
#      HomeTeamWonLast
# 400                1
# 401                1
# 402                0
# 403                0
# 404                1
# 405                0
# 406                0
# 407                0
# 408                1
# 409                0
# 410                0
# 411                0
# 412                0
# 413                1
# 414                0
# 415                0
# 416                0
# 417                0
# 418                0
# 419                0
# 420                1
# 421                1
# 422                0
# 423                1
# 424                0
# 425                0
# 426                0
# 427                0
# 428                0
# 429                1
# 430                0
# 431                0
# 432                1
# 433                1
# 434                0
# 435                0
# 436                0
# 437                0
# 438                0
# 439                0
# 440                0
# 441                0
# 442                1
# 443                0
# 444                0
# 445                1
# 446                1
# 447                0
# 448                0
# 449                1
# 450                0

# %%
#Evaluates as before but includes the new features
X_lastwinner = dataset[[ "HomeTeamWonLast", "HomeTeamRanksHigher", "HomeLastWin", "VisitorLastWin",]].values
clf = DecisionTreeClassifier(random_state=14, criterion="entropy")

scores = cross_val_score(clf, X_lastwinner, y_true, scoring='accuracy')

print("Accuracy: {0:.1f}%".format(np.mean(scores) * 100))
# Out:
# Accuracy: 62.2%
# C:\Users\JRuiz\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)

# %%
#Uses LabelEncoder Transformer to convert string values to assigned integer values, as scikit-learn requires features to be encoded as numbers here
#This is used for both home and visiting team values for consistency
from sklearn.preprocessing import LabelEncoder
encoding = LabelEncoder()
encoding.fit(dataset["Home Team"].values)
home_teams = encoding.transform(dataset["Home Team"].values)
visitor_teams = encoding.transform(dataset["Visitor Team"].values)
X_teams = np.vstack([home_teams, visitor_teams]).T

#In order to fix one inconsistency with continuous features, use OneHotEncoder transformer to encode as number of binary values
from sklearn.preprocessing import OneHotEncoder
onehot = OneHotEncoder()
X_teams = onehot.fit_transform(X_teams).todense()

#Runs the Decision Tree on new dataset 
clf = DecisionTreeClassifier(random_state=14)
scores = cross_val_score(clf, X_teams, y_true, scoring='accuracy')
print("Accuracy: {0:.1f}%".format(np.mean(scores) * 100))
# Out:
# Accuracy: 63.8%
# C:\Users\JRuiz\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\JRuiz\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)

# %%
#Use Estimator interface to use the cross-fold validation
#Ensemble is used to make note of random errors and cancel them out, examines the Variance
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=14)
scores = cross_val_score(clf, X_teams, y_true, scoring='accuracy')
print("Accuracy: {0:.1f}%".format(np.mean(scores) * 100))
# Out:
# C:\Users\JRuiz\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\JRuiz\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\JRuiz\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Accuracy: 64.2%
# C:\Users\JRuiz\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
#Throws more features and runs the classifiers again using RandomForest
X_all = np.hstack([X_lastwinner, X_teams])
clf = RandomForestClassifier(random_state=14)
scores = cross_val_score(clf, X_all, y_true, scoring='accuracy')
print("Accuracy: {0:.1f}%".format(np.mean(scores) * 100))
# Out:
# C:\Users\JRuiz\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\JRuiz\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\JRuiz\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Accuracy: 63.5%
# C:\Users\JRuiz\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
#Runs classifier using n_estimators, which dictates how many decision trees are built
X_all = np.hstack([X_lastwinner, X_teams])
clf = RandomForestClassifier(random_state=14, n_estimators=250)
scores = cross_val_score(clf, X_all, y_true, scoring='accuracy')
print("Accuracy: {0:.1f}%".format(np.mean(scores) * 100))
# Out:
# C:\Users\JRuiz\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# Accuracy: 64.1%

# %%
#Uses other parameters with GridSearchCV to improve the accuracy
from sklearn.model_selection import GridSearchCV
parameter_space = {
    "max_features": [2, 10, 'auto'],
    "n_estimators": [100, 200],
    "criterion": ["gini", "entropy"],
    "min_samples_leaf": [2, 4, 6],
}
clf = RandomForestClassifier(random_state=14)
grid = GridSearchCV(clf, parameter_space)
grid.fit(X_all, y_true)
print("Accuracy: {0:.1f}%".format(grid.best_score_ * 100))
# Out:
# C:\Users\JRuiz\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# Accuracy: 68.0%

# %%
#Prints out the best model with the grid search
print(grid.best_estimator_)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=2, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=2, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=14, verbose=0,
#                        warm_start=False)
